# %% [markdown]
# # Brain age regression
# #### Two main approachs, with all the data from all the runs and the other with the mean matrix correlation for each subject
# # 1. Importing all data or Fisher transformed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set(rc={'image.cmap': 'coolwarm'})

#from numba import jit,prange

import time
import os

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 20

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def import_data(fisher):
    if fisher == True:
        df = pd.read_csv(r'/Users/rodrigo/Post-Grad/CC400/corr_matrices_fisher200.csv',index_col=['Institution','Subject'])
        phenotypic = pd.read_csv(r'/Users/rodrigo/Post-Grad/CC400/phenotypic200.csv',index_col=['Institution','Subject'])
    else:
        df = pd.read_csv(r'/Users/rodrigo/Post-Grad/CC400/corr_matrices200.csv',index_col=['Institution','Subject','Run'])
        phenotypic = pd.read_csv(r'/Users/rodrigo/Post-Grad/CC400/phenotypic200.csv',index_col=['Institution','Subject'])
    return df,phenotypic

# %%
df, phenotypic = import_data(fisher=True)

# %%
df = df.join(pd.DataFrame(phenotypic.Age), how='left')
df = df.join(pd.DataFrame(phenotypic['ADHD Measure']), how='left')
df = df.join(pd.DataFrame(phenotypic['Gender']), how='left')

#df = ((df.reset_index()).drop(columns=['Institution', 'Subject','Run'])).dropna(subset=[str(x) for x in range(0,61425)])
df = ((df.reset_index()).drop(columns=['Institution', 'Subject'])).dropna(subset=[str(x) for x in range(0,17954)])

# %% [markdown]
# ## 2. Starting modelling

# %% [markdown]
# #### Linear Regression

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:,:-3]
y = df.Age

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 10)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)
reg.score(X_test, y_test)
y_pred = reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 1.5279847928079433

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(reg, X, y, cv=5,scoring='neg_mean_absolute_error')
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# -1.95 accuracy with a standard deviation of 0.31

# %%
plt.figure(dpi=200)
plt.scatter(y_pred,y_test,alpha=0.8, edgecolors='black')
plt.ylabel('Predicted Age')
plt.xlabel('Real age')
plt.show()

# %%
plt.hist(reg.coef_,bins=30)
# Out:
# (array([1.000e+00, 2.000e+00, 1.000e+00, 5.000e+00, 5.000e+00, 1.600e+01,
#         1.800e+01, 6.800e+01, 1.200e+02, 2.020e+02, 3.810e+02, 6.850e+02,
#         1.074e+03, 1.600e+03, 2.050e+03, 2.201e+03, 2.395e+03, 2.060e+03,
#         1.818e+03, 1.282e+03, 8.990e+02, 4.910e+02, 3.070e+02, 1.440e+02,
#         7.600e+01, 3.700e+01, 6.000e+00, 7.000e+00, 1.000e+00, 3.000e+00]),
#  array([-0.1046394 , -0.09825795, -0.0918765 , -0.08549505, -0.0791136 ,
#         -0.07273215, -0.0663507 , -0.05996925, -0.0535878 , -0.04720635,
#         -0.04082489, -0.03444344, -0.02806199, -0.02168054, -0.01529909,
#         -0.00891764, -0.00253619,  0.00384526,  0.01022671,  0.01660816,
#          0.02298961,  0.02937106,  0.03575252,  0.04213397,  0.04851542,
#          0.05489687,  0.06127832,  0.06765977,  0.07404122,  0.08042267,
#          0.08680412]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ### Lasso regularization

# %%
from sklearn import linear_model
reg_reg = linear_model.Lasso(alpha=0.1).fit(X_train, y_train)

# %%
reg_reg.score(X_test, y_test)
y_pred = reg_reg.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 1.8620174314166003

# %%
from sklearn.model_selection import GridSearchCV

reg_reg = linear_model.Lasso()

alpha_range = [0.0001,0.0005,0.001]
param_grid =  dict(alpha = alpha_range)

grid = GridSearchCV(reg_reg, param_grid, cv=5, scoring='neg_mean_absolute_error', return_train_score=True,verbose=1)
grid_search=grid.fit(X_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.930e+00, tolerance: 4.760e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.539e+00, tolerance: 4.430e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.761e+00, tolerance: 4.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.045e+00, tolerance: 4.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.778e+00, tolerance: 4.584e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.275e+00, tolerance: 4.760e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.345e+00, tolerance: 4.430e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.372e+00, tolerance: 4.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.726e+00, tolerance: 4.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.830e+00, tolerance: 4.584e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.433e+00, tolerance: 4.760e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.661e+00, tolerance: 4.430e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.808e+00, tolerance: 4.708e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.245e+00, tolerance: 4.348e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.052e+00, tolerance: 4.584e-01
#   model = cd_fast.enet_coordinate_descent(
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.084e+00, tolerance: 5.712e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
print(grid_search.best_params_)
# Out:
# {'alpha': 0.0005}

# %%
accuracy = grid_search.best_score_
print("mean absolute error : {:.2f}".format(accuracy) )
# Out:
# mean absolute error : -1.76

# %%
grid_search.cv_results_
# Out:
# {'mean_fit_time': array([2.16727314, 2.17119441, 2.00798316]),
#  'std_fit_time': array([0.05145142, 0.1414651 , 0.02352201]),
#  'mean_score_time': array([0.04436026, 0.0501987 , 0.04425645]),
#  'std_score_time': array([0.00060893, 0.00572925, 0.0006699 ]),
#  'param_alpha': masked_array(data=[0.0001, 0.0005, 0.001],
#               mask=[False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'alpha': 0.0001}, {'alpha': 0.0005}, {'alpha': 0.001}],
#  'split0_test_score': array([-1.72210112, -1.73858179, -1.71106593]),
#  'split1_test_score': array([-1.81745875, -1.78013877, -1.81142344]),
#  'split2_test_score': array([-1.82914587, -1.76780189, -1.80507991]),
#  'split3_test_score': array([-1.69782089, -1.70523875, -1.65660971]),
#  'split4_test_score': array([-1.91757259, -1.78826977, -1.82840877]),
#  'mean_test_score': array([-1.79681985, -1.75600619, -1.76251755]),
#  'std_test_score': array([0.07929167, 0.03047425, 0.06694585]),
#  'rank_test_score': array([3, 1, 2], dtype=int32),
#  'split0_train_score': array([-0.00510308, -0.02564587, -0.05046358]),
#  'split1_train_score': array([-0.00500928, -0.02545177, -0.05091761]),
#  'split2_train_score': array([-0.00501381, -0.02536424, -0.04939712]),
#  'split3_train_score': array([-0.00512457, -0.02551392, -0.05039533]),
#  'split4_train_score': array([-0.00508612, -0.02503734, -0.05019965]),
#  'mean_train_score': array([-0.00506737, -0.02540263, -0.05027466]),
#  'std_train_score': array([4.72056863e-05, 2.04390546e-04, 4.97863750e-04])}

# %% [markdown]
# ### After fiding the best hyper-parameter

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

reg_reg = linear_model.Lasso(alpha=0.001).fit(X_train, y_train)
y_pred = reg_reg.predict(X_test)

print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 1.7899733492555598
# 4.985081595541195
# /opt/homebrew/Caskroom/miniforge/base/envs/fmri/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.075e+01, tolerance: 5.712e-01
#   model = cd_fast.enet_coordinate_descent(

# %%
plt.figure(dpi=200)
plt.scatter(y_test,y_pred,alpha=0.8, edgecolors='black')
plt.ylabel('Predicted Age')
plt.xlabel('Real age')
plt.title(('r = {:.2f}'.format(np.corrcoef(y_test,y_pred)[0,1])))
plt.show()

# %%
df_aux = df.loc[list(y_test.index),:]
df_aux['Predicted Age'] = y_pred

# %%
plt.figure(dpi=150)
sns.scatterplot(data=df_aux, x='Age', y='Predicted Age', hue='ADHD Measure')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Predicted Age'>

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

#result = smf.ols('falsexam ~ format_ol', data=df).fit()
model = sm.OLS(y_train,X_train)
results = model.fit()
result.summary().tables[1]

# %%
from statsmodels.tools.tools import pinv_extended
import statsmodels.api as sm
import sklearn, statsmodels

def regression_analysis(X, y, model):
    
    is_statsmodels = False
    is_sklearn = False
    
    # check for accepted linear models
    if type(model) in [sklearn.linear_model._base.LinearRegression,
                       sklearn.linear_model._ridge.Ridge,
                       sklearn.linear_model._ridge.RidgeCV,
                       sklearn.linear_model._coordinate_descent.Lasso,
                       sklearn.linear_model._coordinate_descent.LassoCV,
                       sklearn.linear_model._coordinate_descent.ElasticNet,
                       sklearn.linear_model._coordinate_descent.ElasticNetCV,
                      ]:
        is_sklearn = True
    elif type(model) in [statsmodels.regression.linear_model.OLS, 
                         statsmodels.base.elastic_net.RegularizedResults,
                        ]:
        is_statsmodels = True
    else:
        print("Only linear models are supported!")
        return None
    
    
    
    has_intercept = False
    
    if is_statsmodels and all(np.array(X)[:,0]==1):
        # statsmodels add_constant has been used already
        has_intercept = True  
    elif is_sklearn and model.intercept_:
        has_intercept = True
        

    
    if is_statsmodels:
        # add_constant has been used already
        x = X
        model_params = model.params
    else: # sklearn model
        if has_intercept:
            x = sm.add_constant(X)
            model_params = np.hstack([np.array([model.intercept_]), model.coef_])
        else:
            x = X
            model_params = model.coef_
        
    #y = np.array(y).ravel()
    
    # define the OLS model
    olsModel = sm.OLS(y, x)
    
    pinv_wexog,_ = pinv_extended(x)
    normalized_cov_params = np.dot(pinv_wexog, np.transpose(pinv_wexog))
    
    
    return sm.regression.linear_model.OLSResults(olsModel, model_params, normalized_cov_params)

# %%
from sklearn.linear_model import Ridge


skridge = Ridge(alpha=0.2, max_iter=9000, tol=1e-5, fit_intercept=True)
skridge.fit(X_train,y_train)

result = regression_analysis(X_train, y_train, skridge)
result.summary()

# %% [markdown]
# ## Pycaret

# %% [markdown]
# ### PCA

# %%
# from sklearn.decomposition import PCA


# # PCA
# pca = PCA(n_components=100)
# XPCA_train = pca.fit_transform(X_train)
# XPCA_test = pca.fit_transform(X_test)

# %%
# XPCA_train = pd.DataFrame(XPCA_train)
# XPCA_train['Age'] = y_train.values
# XPCA_train = XPCA_train.dropna()

# XPCA_test = pd.DataFrame(XPCA_test)
# XPCA_test['Age'] = y_test.values
# XPCA_test = XPCA_test.dropna()

# %%
from pycaret.regression import *
s = setup(df, target = 'Age')

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_4d8cb th {
#   text-align: left;
# }
# #T_4d8cb_row0_col0, #T_4d8cb_row1_col0, #T_4d8cb_row1_col1, #T_4d8cb_row1_col2, #T_4d8cb_row1_col3, #T_4d8cb_row1_col4, #T_4d8cb_row1_col5, #T_4d8cb_row1_col6, #T_4d8cb_row2_col0, #T_4d8cb_row2_col1, #T_4d8cb_row2_col2, #T_4d8cb_row2_col3, #T_4d8cb_row2_col4, #T_4d8cb_row2_col5, #T_4d8cb_row2_col6, #T_4d8cb_row3_col0, #T_4d8cb_row3_col1, #T_4d8cb_row3_col2, #T_4d8cb_row3_col3, #T_4d8cb_row3_col4, #T_4d8cb_row3_col5, #T_4d8cb_row3_col6, #T_4d8cb_row4_col0, #T_4d8cb_row4_col1, #T_4d8cb_row4_col2, #T_4d8cb_row4_col3, #T_4d8cb_row4_col4, #T_4d8cb_row4_col5, #T_4d8cb_row4_col6, #T_4d8cb_row5_col0, #T_4d8cb_row5_col1, #T_4d8cb_row5_col2, #T_4d8cb_row5_col3, #T_4d8cb_row5_col4, #T_4d8cb_row5_col5, #T_4d8cb_row5_col6, #T_4d8cb_row6_col0, #T_4d8cb_row6_col1, #T_4d8cb_row6_col2, #T_4d8cb_row6_col3, #T_4d8cb_row6_col4, #T_4d8cb_row6_col5, #T_4d8cb_row6_col6, #T_4d8cb_row7_col0, #T_4d8cb_row7_col1, #T_4d8cb_row7_col2, #T_4d8cb_row7_col3, #T_4d8cb_row7_col4, #T_4d8cb_row7_col5, #T_4d8cb_row7_col6, #T_4d8cb_row8_col0, #T_4d8cb_row8_col1, #T_4d8cb_row8_col2, #T_4d8cb_row8_col3, #T_4d8cb_row8_col4, #T_4d8cb_row8_col5, #T_4d8cb_row8_col6, #T_4d8cb_row9_col0, #T_4d8cb_row9_col1, #T_4d8cb_row9_col2, #T_4d8cb_row9_col3, #T_4d8cb_row9_col4, #T_4d8cb_row9_col5, #T_4d8cb_row9_col6, #T_4d8cb_row10_col0, #T_4d8cb_row10_col1, #T_4d8cb_row10_col2, #T_4d8cb_row10_col3, #T_4d8cb_row10_col4, #T_4d8cb_row10_col5, #T_4d8cb_row10_col6, #T_4d8cb_row11_col0, #T_4d8cb_row11_col1, #T_4d8cb_row11_col2, #T_4d8cb_row11_col3, #T_4d8cb_row11_col4, #T_4d8cb_row11_col5, #T_4d8cb_row11_col6, #T_4d8cb_row12_col0, #T_4d8cb_row12_col1, #T_4d8cb_row12_col2, #T_4d8cb_row12_col3, #T_4d8cb_row12_col4, #T_4d8cb_row12_col5, #T_4d8cb_row12_col6, #T_4d8cb_row13_col0, #T_4d8cb_row13_col1, #T_4d8cb_row13_col2, #T_4d8cb_row13_col3, #T_4d8cb_row13_col4, #T_4d8cb_row13_col5, #T_4d8cb_row13_col6, #T_4d8cb_row14_col0, #T_4d8cb_row14_col1, #T_4d8cb_row14_col2, #T_4d8cb_row14_col3, #T_4d8cb_row14_col4, #T_4d8cb_row14_col5, #T_4d8cb_row14_col6, #T_4d8cb_row15_col0, #T_4d8cb_row15_col1, #T_4d8cb_row15_col2, #T_4d8cb_row15_col3, #T_4d8cb_row15_col4, #T_4d8cb_row15_col5, #T_4d8cb_row15_col6, #T_4d8cb_row16_col0, #T_4d8cb_row16_col1, #T_4d8cb_row16_col2, #T_4d8cb_row16_col3, #T_4d8cb_row16_col4, #T_4d8cb_row16_col5, #T_4d8cb_row16_col6, #T_4d8cb_row17_col0, #T_4d8cb_row17_col1, #T_4d8cb_row17_col2, #T_4d8cb_row17_col3, #T_4d8cb_row17_col4, #T_4d8cb_row17_col5, #T_4d8cb_row17_col6 {
#   text-align: left;
# }
# #T_4d8cb_row0_col1, #T_4d8cb_row0_col2, #T_4d8cb_row0_col3, #T_4d8cb_row0_col4, #T_4d8cb_row0_col5, #T_4d8cb_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4d8cb_row0_col7, #T_4d8cb_row1_col7, #T_4d8cb_row2_col7, #T_4d8cb_row3_col7, #T_4d8cb_row4_col7, #T_4d8cb_row5_col7, #T_4d8cb_row6_col7, #T_4d8cb_row7_col7, #T_4d8cb_row8_col7, #T_4d8cb_row9_col7, #T_4d8cb_row10_col7, #T_4d8cb_row11_col7, #T_4d8cb_row12_col7, #T_4d8cb_row13_col7, #T_4d8cb_row14_col7, #T_4d8cb_row15_col7, #T_4d8cb_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4d8cb_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4d8cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d8cb_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4d8cb_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4d8cb_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4d8cb_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4d8cb_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4d8cb_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4d8cb_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4d8cb_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d8cb_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_4d8cb_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4d8cb_row0_col1" class="data row0 col1" >1.4086</td>
#       <td id="T_4d8cb_row0_col2" class="data row0 col2" >3.3359</td>
#       <td id="T_4d8cb_row0_col3" class="data row0 col3" >1.8219</td>
#       <td id="T_4d8cb_row0_col4" class="data row0 col4" >0.6735</td>
#       <td id="T_4d8cb_row0_col5" class="data row0 col5" >0.1395</td>
#       <td id="T_4d8cb_row0_col6" class="data row0 col6" >0.1242</td>
#       <td id="T_4d8cb_row0_col7" class="data row0 col7" >0.1900</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_4d8cb_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_4d8cb_row1_col1" class="data row1 col1" >1.5484</td>
#       <td id="T_4d8cb_row1_col2" class="data row1 col2" >3.8692</td>
#       <td id="T_4d8cb_row1_col3" class="data row1 col3" >1.9649</td>
#       <td id="T_4d8cb_row1_col4" class="data row1 col4" >0.6217</td>
#       <td id="T_4d8cb_row1_col5" class="data row1 col5" >0.1518</td>
#       <td id="T_4d8cb_row1_col6" class="data row1 col6" >0.1392</td>
#       <td id="T_4d8cb_row1_col7" class="data row1 col7" >0.2880</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row2" class="row_heading level0 row2" >br</th>
#       <td id="T_4d8cb_row2_col0" class="data row2 col0" >Bayesian Ridge</td>
#       <td id="T_4d8cb_row2_col1" class="data row2 col1" >1.5489</td>
#       <td id="T_4d8cb_row2_col2" class="data row2 col2" >3.9282</td>
#       <td id="T_4d8cb_row2_col3" class="data row2 col3" >1.9776</td>
#       <td id="T_4d8cb_row2_col4" class="data row2 col4" >0.6154</td>
#       <td id="T_4d8cb_row2_col5" class="data row2 col5" >0.1635</td>
#       <td id="T_4d8cb_row2_col6" class="data row2 col6" >0.1385</td>
#       <td id="T_4d8cb_row2_col7" class="data row2 col7" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_4d8cb_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_4d8cb_row3_col1" class="data row3 col1" >1.5568</td>
#       <td id="T_4d8cb_row3_col2" class="data row3 col2" >3.9614</td>
#       <td id="T_4d8cb_row3_col3" class="data row3 col3" >1.9859</td>
#       <td id="T_4d8cb_row3_col4" class="data row3 col4" >0.6117</td>
#       <td id="T_4d8cb_row3_col5" class="data row3 col5" >0.1638</td>
#       <td id="T_4d8cb_row3_col6" class="data row3 col6" >0.1398</td>
#       <td id="T_4d8cb_row3_col7" class="data row3 col7" >0.3220</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_4d8cb_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_4d8cb_row4_col1" class="data row4 col1" >1.5568</td>
#       <td id="T_4d8cb_row4_col2" class="data row4 col2" >3.9613</td>
#       <td id="T_4d8cb_row4_col3" class="data row4 col3" >1.9859</td>
#       <td id="T_4d8cb_row4_col4" class="data row4 col4" >0.6117</td>
#       <td id="T_4d8cb_row4_col5" class="data row4 col5" >0.1638</td>
#       <td id="T_4d8cb_row4_col6" class="data row4 col6" >0.1398</td>
#       <td id="T_4d8cb_row4_col7" class="data row4 col7" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_4d8cb_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_4d8cb_row5_col1" class="data row5 col1" >1.5568</td>
#       <td id="T_4d8cb_row5_col2" class="data row5 col2" >3.9614</td>
#       <td id="T_4d8cb_row5_col3" class="data row5 col3" >1.9859</td>
#       <td id="T_4d8cb_row5_col4" class="data row5 col4" >0.6117</td>
#       <td id="T_4d8cb_row5_col5" class="data row5 col5" >0.1638</td>
#       <td id="T_4d8cb_row5_col6" class="data row5 col6" >0.1398</td>
#       <td id="T_4d8cb_row5_col7" class="data row5 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_4d8cb_level0_row6" class="row_head

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
bayesian_bridge = create_model('br') 
tuned_bayesian_bridge = tune_model(bayesian_bridge)
# Out:
# <style type="text/css">
# #T_9eac3_row10_col0, #T_9eac3_row10_col1, #T_9eac3_row10_col2, #T_9eac3_row10_col3, #T_9eac3_row10_col4, #T_9eac3_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9eac3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eac3_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9eac3_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9eac3_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9eac3_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9eac3_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9eac3_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eac3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9eac3_row0_col0" class="data row0 col0" >1.6658</td>
#       <td id="T_9eac3_row0_col1" class="data row0 col1" >4.2578</td>
#       <td id="T_9eac3_row0_col2" class="data row0 col2" >2.0634</td>
#       <td id="T_9eac3_row0_col3" class="data row0 col3" >0.5711</td>
#       <td id="T_9eac3_row0_col4" class="data row0 col4" >0.1666</td>
#       <td id="T_9eac3_row0_col5" class="data row0 col5" >0.1512</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9eac3_row1_col0" class="data row1 col0" >1.6958</td>
#       <td id="T_9eac3_row1_col1" class="data row1 col1" >5.2148</td>
#       <td id="T_9eac3_row1_col2" class="data row1 col2" >2.2836</td>
#       <td id="T_9eac3_row1_col3" class="data row1 col3" >0.4790</td>
#       <td id="T_9eac3_row1_col4" class="data row1 col4" >0.2467</td>
#       <td id="T_9eac3_row1_col5" class="data row1 col5" >0.1553</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9eac3_row2_col0" class="data row2 col0" >1.4547</td>
#       <td id="T_9eac3_row2_col1" class="data row2 col1" >3.3245</td>
#       <td id="T_9eac3_row2_col2" class="data row2 col2" >1.8233</td>
#       <td id="T_9eac3_row2_col3" class="data row2 col3" >0.5452</td>
#       <td id="T_9eac3_row2_col4" class="data row2 col4" >0.1509</td>
#       <td id="T_9eac3_row2_col5" class="data row2 col5" >0.1375</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9eac3_row3_col0" class="data row3 col0" >1.4244</td>
#       <td id="T_9eac3_row3_col1" class="data row3 col1" >3.2533</td>
#       <td id="T_9eac3_row3_col2" class="data row3 col2" >1.8037</td>
#       <td id="T_9eac3_row3_col3" class="data row3 col3" >0.6992</td>
#       <td id="T_9eac3_row3_col4" class="data row3 col4" >0.1429</td>
#       <td id="T_9eac3_row3_col5" class="data row3 col5" >0.1252</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9eac3_row4_col0" class="data row4 col0" >1.4894</td>
#       <td id="T_9eac3_row4_col1" class="data row4 col1" >3.8910</td>
#       <td id="T_9eac3_row4_col2" class="data row4 col2" >1.9725</td>
#       <td id="T_9eac3_row4_col3" class="data row4 col3" >0.6241</td>
#       <td id="T_9eac3_row4_col4" class="data row4 col4" >0.1528</td>
#       <td id="T_9eac3_row4_col5" class="data row4 col5" >0.1296</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9eac3_row5_col0" class="data row5 col0" >1.4932</td>
#       <td id="T_9eac3_row5_col1" class="data row5 col1" >3.6891</td>
#       <td id="T_9eac3_row5_col2" class="data row5 col2" >1.9207</td>
#       <td id="T_9eac3_row5_col3" class="data row5 col3" >0.6702</td>
#       <td id="T_9eac3_row5_col4" class="data row5 col4" >0.1457</td>
#       <td id="T_9eac3_row5_col5" class="data row5 col5" >0.1301</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9eac3_row6_col0" class="data row6 col0" >1.5380</td>
#       <td id="T_9eac3_row6_col1" class="data row6 col1" >3.6971</td>
#       <td id="T_9eac3_row6_col2" class="data row6 col2" >1.9228</td>
#       <td id="T_9eac3_row6_col3" class="data row6 col3" >0.6553</td>
#       <td id="T_9eac3_row6_col4" class="data row6 col4" >0.1483</td>
#       <td id="T_9eac3_row6_col5" class="data row6 col5" >0.1331</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9eac3_row7_col0" class="data row7 col0" >1.5342</td>
#       <td id="T_9eac3_row7_col1" class="data row7 col1" >3.8791</td>
#       <td id="T_9eac3_row7_col2" class="data row7 col2" >1.9695</td>
#       <td id="T_9eac3_row7_col3" class="data row7 col3" >0.6516</td>
#       <td id="T_9eac3_row7_col4" class="data row7 col4" >0.1635</td>
#       <td id="T_9eac3_row7_col5" class="data row7 col5" >0.1384</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9eac3_row8_col0" class="data row8 col0" >1.6383</td>
#       <td id="T_9eac3_row8_col1" class="data row8 col1" >4.2893</td>
#       <td id="T_9eac3_row8_col2" class="data row8 col2" >2.0711</td>
#       <td id="T_9eac3_row8_col3" class="data row8 col3" >0.5731</td>
#       <td id="T_9eac3_row8_col4" class="data row8 col4" >0.1649</td>
#       <td id="T_9eac3_row8_col5" class="data row8 col5" >0.1483</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9eac3_row9_col0" class="data row9 col0" >1.5544</td>
#       <td id="T_9eac3_row9_col1" class="data row9 col1" >3.7855</td>
#       <td id="T_9eac3_row9_col2" class="data row9 col2" >1.9456</td>
#       <td id="T_9eac3_row9_col3" class="data row9 col3" >0.6847</td>
#       <td id="T_9eac3_row9_col4" class="data row9 col4" >0.1525</td>
#       <td id="T_9eac3_row9_col5" class="data row9 col5" >0.1361</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9eac3_row10_col0" class="data row10 col0" >1.5488</td>
#       <td id="T_9eac3_row10_col1" class="data row10 col1" >3.9281</td>
#       <td id="T_9eac3_row10_col2" class="data row10 col2" >1.9776</td>
#       <td id="T_9eac3_row10_col3" class="data row10 col3" >0.6154</td>
#       <td id="T_9eac3_row10_col4" class="data row10 col4" >0.1635</td>
#       <td id="T_9eac3_row10_col5" class="data row10 col5" >0.1385</td>
#     </tr>
#     <tr>
#       <th id="T_9eac3_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_9eac3_row11_col0" class="data row11 col0" >0.0864</td>
#       <td id="T_9eac3_row11_col1" class="data row11 col1" >0.5338</td>
#       <td id="T_9eac3_row11_col2" class="data row11 col2" >0.1308</td>
#       <td id="T_9eac3_row11_col3" class="data row11 col3" >0.0671</td>
#       <td id="T_9eac3_row11_col4" class="data row11 col4" >0.0288</td>
#       <td id="T_9eac3_row11_col5" class="data row11 col5" >0.0095</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions = predict_model(tuned_bayesian_bridge)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f85e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f85e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7f85e_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7f85e_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7f85e_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7f85e_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7f85e_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7f85e_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f85e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f85e_row0_col0" class="data row0 col0" >Bayesian Ridge</td>
#       <td id="T_7f85e_row0_col1" class="data row0 col1" >3.0176</td>
#       <td id="T_7f85e_row0_col2" class="data row0 col2" >14.5265</td>
#       <td id="T_7f85e_row0_col3" class="data row0 col3" >3.8114</td>
#       <td id="T_7f85e_row0_col4" class="data row0 col4" >-0.4822</td>
#       <td id="T_7f85e_row0_col5" class="data row0 col5" >0.3192</td>
#       <td id="T_7f85e_row0_col6" class="data row0 col6" >0.2792</td>
#     </tr>
#   </tbody>
# </table>

# %%
predictions.shape
# Out:
# (710, 102)

# %%
plt.figure(dpi=200)
plt.scatter(predictions.Age,predictions.Label,alpha=0.8, edgecolors='black')
plt.ylabel('Predicted Age')
plt.xlabel('Real age')
plt.show()
